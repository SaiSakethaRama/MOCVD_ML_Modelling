# %%
from tensorflow.keras import backend as K
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau
from keras.layers import Input, Dense, Lambda,Conv1D,Conv2DTranspose, LeakyReLU,Activation,Flatten,Reshape
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.models import load_model
import emcee
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2025-07-25 19:07:17.891450: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-25 19:07:18.080813: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753470438.176620   36112 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753470438.204543   36112 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753470438.354525   36112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753470438.354604   36112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753470438.354612   36112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1753470438.354614   36112 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-07-25 19:07:18.385774: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
JV_raw = np.loadtxt("/mnt/c/Users/pssrg/Downloads/GaAs_sim_nJV.txt")
par = np.loadtxt("/mnt/c/Users/pssrg/Downloads/GaAs_sim_label.txt")

# %%
print(JV_raw.shape)
print(par.shape)
# Out:
# (19999, 500)
# (19999, 5)

# %%
def Conv1DTranspose(input_tensor, filters, kernel_size, strides ):
    
    x = Lambda(lambda x: K.expand_dims(x, axis=2))(input_tensor)
    x = Conv2DTranspose(filters=filters, kernel_size=(kernel_size, 1), strides=(strides, 1),padding='SAME')(x)
    x = Lambda(lambda x: K.squeeze(x, axis=2))(x)
    return x

#Covert labels from log10 form to log
        
def log10_ln(x):
    return np.log(np.power(10,x))

par = log10_ln(par)


#Data normalization for the whole JV dataset

def min_max(x):
    min = np.min(x)
    max = np.max(x)
    return (x-min)/(max-min),max,min

#Normalize raw JV data

JV_norm,JV_max,JV_min = min_max(JV_raw)

#Normalize JV descriptors column-wise
scaler = MinMaxScaler()

par_n = scaler.fit_transform(par)   

#create training and testing datset

X_train, X_test, y_train, y_test = train_test_split(JV_norm,par_n, test_size=0.2)

#add in Gaussian noise to train the denoising Autoencoder

X_train_nos = X_train+0.002 * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape) 

X_test_nos = X_test+0.002 * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape)

# %%
plt.plot(X_train[0,:])
plt.xlabel('voltage(a.u.)')
plt.ylabel('current(a.u.)')
# Out:
# Text(0, 0.5, 'current(a.u.)')

# %%
input_dim = X_train.shape[1]
label_dim = y_train.shape[1]

max_filter = 256
strides = [5, 2, 2]
kernel = [7, 5, 3]
batch_size = 128
x = Input(shape=(input_dim,))  # JVi (noisy input)

def encoder(x):
    x = Lambda(lambda x: K.expand_dims(x, axis=2), output_shape=lambda s: (s[0], s[1], 1))(x)
    en0 = Conv1D(max_filter // 4, kernel[0], strides=strides[0], padding='same')(x)
    en0 = LeakyReLU(0.2)(en0)
    en1 = Conv1D(max_filter // 2, kernel[1], strides=strides[1], padding='same')(en0)
    en1 = LeakyReLU(0.2)(en1)
    en2 = Conv1D(max_filter, kernel[2], strides=strides[2], padding='same')(en1)
    en2 = LeakyReLU(0.2)(en2)
    en3 = Flatten()(en2)
    en3 = Dense(100, activation='relu')(en3)
    z = Dense(label_dim, activation='linear')(en3)
    return z

z = encoder(x)
encoder_model = Model(x, z)
map_size = K.int_shape(encoder_model.layers[-4].output)[1]  # From last Conv1D

# ----------- Decoder -----------
z1 = Dense(100, activation='relu')(z)
z1 = Dense(max_filter * map_size, activation='relu')(z1)
z1 = Reshape((map_size, 1, max_filter))(z1)
z2 = Conv2DTranspose(max_filter // 2, (kernel[2], 1), strides=(strides[2], 1), padding='same')(z1)
z2 = Activation('relu')(z2)
z3 = Conv2DTranspose(max_filter // 4, (kernel[1], 1), strides=(strides[1], 1), padding='same')(z2)
z3 = Activation('relu')(z3)
z4 = Conv2DTranspose(1, (kernel[0], 1), strides=(strides[0], 1), padding='same')(z3)
decoded_x = Activation('sigmoid')(z4)
decoded_x = Lambda(lambda x: K.squeeze(x, axis=2), output_shape=lambda s: (s[0], s[1], s[3]))(decoded_x)
decoded_x = Lambda(lambda x: K.squeeze(x, axis=2), output_shape=lambda s: (s[0], s[1]))(decoded_x)

# Denoising Autoencoder Model
ae = Model(inputs=x, outputs=decoded_x)

# ----------- Loss Function -----------
def ae_loss(x_true, x_pred):
    return K.mean(K.sum(K.square(x_true - x_pred), axis=-1))

ae.compile(optimizer='adam', loss=ae_loss)

# Reduce learning rate callback
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, min_lr=1e-5)

# ----------- Train Autoencoder -----------
ae.fit(
    X_train_nos,
    X_train,
    shuffle=True,
    batch_size=batch_size,
    epochs=50,
    validation_split=0.0,
    callbacks=[reduce_lr]
)
# Out:
# I0000 00:00:1753470971.833304   36112 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753470980.536555   37748 service.cc:152] XLA service 0x7f1ef40122d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753470980.537345   37748 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2025-07-25 19:16:20.721979: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1753470981.302766   37748 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-07-25 19:16:23.576713: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 60 bytes spill stores, 60 bytes spill loads
#
# 2025-07-25 19:16:23.669862: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 348 bytes spill stores, 348 bytes spill loads
#
# 2025-07-25 19:16:24.132292: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 380 bytes spill stores, 380 bytes spill loads
#
# 2025-07-25 19:16:24.162838: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542_0', 128 bytes spill stores, 128 bytes spill loads
#
# 2025-07-25 19:16:24.273539: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 76 bytes spill stores, 92 bytes spill loads
#
# 2025-07-25 19:16:24.500609: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_879', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-07-25 19:16:24.573037: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 392 bytes spill stores, 392 bytes spill loads
#
# 2025-07-25 19:16:24.881923: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 268 bytes spill stores, 268 bytes spill loads
#
# 2025-07-25 19:16:25.227084: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 268 bytes spill stores, 268 bytes spill loads
#
# 2025-07-25 19:16:25.473797: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-07-25 19:16:25.690739: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-07-25 19:16:25.759374: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-07-25 19:16:25.898703: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881_0', 208 bytes spill stores, 208 bytes spill loads
#   7/125 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 32.0863
# I0000 00:00:1753470991.007235   37748 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 122/125 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0566
# 2025-07-25 19:16:34.144910: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542_0', 108 bytes spill stores, 108 bytes spill loads
#
# 2025-07-25 19:16:34.214098: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_531', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-07-25 19:16:34.299473: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 464 bytes spill stores, 464 bytes spill loads
#
# 2025-07-25 19:16:34.349828: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 240 bytes spill stores, 240 bytes spill loads
#
# 2025-07-25 19:16:34.412082: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 368 bytes spill stores, 368 bytes spill loads
#
# 2025-07-25 19:16:35.006291: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-07-25 19:16:35.142906: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 348 bytes spill stores, 348 bytes spill loads
#
# 2025-07-25 19:16:35.394421: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 416 bytes spill stores, 416 bytes spill loads
#
# 2025-07-25 19:16:35.414421: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_877', 68 bytes spill stores, 68 bytes spill loads
#
# 2025-07-25 19:16:35.519615: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 416 bytes spill stores, 416 bytes spill loads
#
# 2025-07-25 19:16:35.569853: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 84 bytes spill stores, 84 bytes spill loads
#
# 2025-07-25 19:16:35.968436: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 456 bytes spill stores, 456 bytes spill loads
#
# 2025-07-25 19:16:36.018519: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 32 bytes spill stores, 32 bytes spill loads
#
# 2025-07-25 19:16:36.149131: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_542', 24 bytes spill stores, 24 bytes spill loads
#
# 2025-07-25 19:16:36.238759: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881_0', 208 bytes spill stores, 208 bytes spill loads
#
# 2025-07-25 19:16:36.317714: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 584 bytes spill stores, 584 bytes spill loads
#
# 2025-07-25 19:16:36.318212: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 192 bytes spill stores, 192 bytes spill loads
#
# 2025-07-25 19:16:36.468114: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 492 bytes spill stores, 492 bytes spill loads
#
# 2025-07-25 19:16:36.647967: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_881', 820 bytes spill stores, 820 bytes spill loads
#
# 2025-07-25 19:16:42.213768: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.14 = (f32[128,64,5,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[127,64,101,1]{3,2,1,0} %bitcast.4478, f32[127,128,50,1]{3,2,1,0} %bitcast.4480), window={size=5x1 stride=2x1 pad=1_1x0_0}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/functional_1_1/conv2d_transpose_1_2/conv_transpose/Conv2DBackpropFilter" source_file="/home/pssrg/First_Year_Summer_Project/tf/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-07-25 19:16:42.214269: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.516755002s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.14 = (f32[128,64,5,1]{3,2,1,0}, u8[0]{0}) custom-call(f32[127,64,101,1]{3,2,1,0} %bitcast.4478, f32[127,128,50,1]{3,2,1,0} %bitcast.4480), window={size=5x1 stride=2x1 pad=1_1x0_0}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/functional_1_1/conv2d_transpose_1_2/conv_transpose/Conv2DBackpropFilter" source_file="/home/pssrg/First_Year_Summer_Project/tf/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - loss: 7.8927 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5580 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1159 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1048 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0887 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0654 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0318 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0227 - learning_rate: 0.0010
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0162 - learning_rate: 0.0010
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0194 - learning_rate: 0.0010
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0095 - learning_rate: 0.0010
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0072 - learning_rate: 0.0010
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0078 - learning_rate: 0.0010
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0098 - learning_rate: 0.0010
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0101 - learning_rate: 0.0010
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - learning_rate: 0.0010
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0037 - learning_rate: 0.0010
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0038 - learning_rate: 0.0010
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - learning_rate: 0.0010
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0036 - learning_rate: 0.0010
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - learning_rate: 0.0010
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0056 - learning_rate: 0.0010
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0031 - learning_rate: 0.0010
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0052 - learning_rate: 0.0010
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0040 - learning_rate: 0.0010
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - learning_rate: 0.0010
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - learning_rate: 0.0010
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0041 - learning_rate: 0.0010
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - loss: 0.0014 - learning_rate: 5.0000e-04
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0015 - learning_rate: 5.0000e-04
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0013 - learning_rate: 2.5000e-04
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - learning_rate: 1.2500e-04
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - learning_rate: 1.2500e-04
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0011 - learning_rate: 1.2500e-04
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - learning_rate: 1.2500e-04
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - learning_rate: 1.2500e-04
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0011 - learning_rate: 1.2500e-04
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0011 - learning_rate: 6.2500e-05
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0011 - learning_rate: 6.2500e-05

# %%
x_test_decoded= ae.predict(X_test_nos)
rand_ind = np.random.randint(0,100)
plt.plot(x_test_decoded[rand_ind,:],label='AE')
plt.plot(X_test_nos[rand_ind,:],'--',label='raw')
plt.legend()
plt.show()
# Out:
# 2025-07-25 19:17:32.968164: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_95', 20 bytes spill stores, 20 bytes spill loads
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step

# %%
ae.save('./TrainedModel/GaAs_AE.keras')
